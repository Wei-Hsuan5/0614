# %% [markdown]
# <a href="https://colab.research.google.com/github/Wei-Hsuan5/0614/blob/main/L12_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **製作圓餅圖**

# %%
import matplotlib.pyplot as plt

labels = ['Cocktails', 'Beer', 'Soju', 'Spirits']
values = [20, 35, 30, 10]
colors = ['pink', 'green', 'teal', 'gray']
explode = [0, 0, 0.1, 0]

_, _, autotexts=plt.pie(values, labels=labels, colors=colors, explode=explode, shadow= True, startangle=-30, autopct='%1.1f%%')
plt.setp(autotexts, size=10, color='white')
plt.show()
